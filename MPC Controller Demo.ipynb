# %% [markdown]
# # MPC Controller Demo

# %%
include("mpc_controller.jl")
# Out:
# mpcController (generic function with 3 methods)

# %%
mpcController(0.0, [0.0, 0.0, 3.0, 0.0], [-4.0, 4.0, 0.0, 3/2*pi], true)
# Out:
# Figure(PyObject <Figure size 600x500 with 1 Axes>)
# 2-element Vector{Float64}:
#  0.0
#  0.0
